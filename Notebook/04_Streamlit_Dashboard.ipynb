# %% [markdown]
# # 04 - Streamlit Dashboard
# واجهة Streamlit محفوظة في `Output/app/streamlit_app.py` وتقرأ فقط artifacts التي أنشأتها نوتبوكات التحليل.

# %%
from pathlib import Path
import ast

PROJECT_ROOT = Path.cwd().resolve()
if PROJECT_ROOT.name == 'Notebook':
    PROJECT_ROOT = PROJECT_ROOT.parent
APP_PATH = PROJECT_ROOT / 'Output' / 'app' / 'streamlit_app.py'

ast.parse(APP_PATH.read_text(encoding='utf-8'))
print(f'Dashboard source is valid: {APP_PATH.relative_to(PROJECT_ROOT)}')
print('Run it from Notebook/05_Run_All.ipynb or use:')
print(f'  streamlit run {APP_PATH}')
# Out:
# Dashboard source is valid: Output\app\streamlit_app.py
# Run it from Notebook/05_Run_All.ipynb or use:
#   streamlit run C:\my\Projectes\DeepLearning\Retail_Intelligence_Agent\Output\app\streamlit_app.py

# %% [markdown]
# الواجهة تشمل: الحالة الحالية، الطوابير والتوقع، تحليلات المناطق، سجل التنبيهات، وسؤال عربي محدود ومؤمّن على بيانات المتجر المحلية.
